# %%
from facebook_scraper import get_posts
import pandas as pd
import numpy as np
import time

# %%
FANPAGE_LINK ="internetexplorerbeta"
FOLDER_PATH = "Data"
COOKIE_PATH = "tet.txt"

PAGES_NUMBER = 500 # Number of pages to crawl

# %%
post_list = []
count = 0
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
# Lưu trữ các tên cột bạn muốn giữ lại
desired_columns = ["comments", "reactions", "timestamp", "post_id", "post_text", "user_id", "time", "shares", "post_url",
                              "image", "images_description", "likes", "username", "user_url", "is_live",
                              "reaction_count", "page_id"]
for post in get_posts(FANPAGE_LINK,
                    options={"comments": True, "reactions": True, "timestap": True,"post_id": True, "post_text":True,"user_id": True, "time":True,"shares":True,"post_url":True,
                              "image":True, "images_description":True, "likes":True, "username":True, "user_url":True,"reaction_count":True," page_id":True, "header":headers},
                    pages=PAGES_NUMBER, cookies=COOKIE_PATH):
    # Lọc các cột dựa trên tên cột mong muốn
    filtered_post = {key: value for key, value in post.items() if key in desired_columns}
    post_list.append(filtered_post)
    print(filtered_post)
    time.sleep(10)
    count += 1
    if count == 1000:
        break

# %%
print(len(post_list))
# Out:
# 190

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# To df
path=FOLDER_PATH + FANPAGE_LINK + ".csv"
post_df_full.to_csv(path, index=False)
print(path)
# Out:
# Datainternetexplorerbeta.csv

# %%
post_df_full
# Out:
#              post_id                                          post_text  \
# 0    745120894321144  SINH NHẬT TUỔI 25, KHÁ BẢNH ĐƯỢC TẶNG XE GA PC...
# 1    745027654330468  XUẤT HIỆN 5 ANH EM SIÊU NHÂN TRÊN PHỐ ĐI BỘ HỒ...
# 2    744800524353181    Roooneyyyyyyyyy !!!! Thật không thể tin được!!!
# 3    744235994409634                                     Con j day ae 👇
# 4    744197157746851  TUYỆT CHIÊU TỪ TPBANK 2IN1 CONCERT QUÁ CUỐN ‼️...
# ..               ...                                                ...
# 185  704914125008488  -= QUẢNG CÁO YEUPHONE, ĐIỆN THOẠI HOT NHẤT THẾ...
# 186  704850765014824  Câu chuyện cảm lạnh khi mua mỹ phẩm cùng với b...
# 187  704783645021536             Trẻ con mới chọn, người lớn lấy hếtt 😎
# 188  704442931722274  Sốc: Vé xem phim rẻ như bát phở!!\nĐặt ngay tr...
# 189  704383961728171  Trung thu sao sáng, da sáng hơn sao 💫🏮\n\nDạo ...
#
#                    time   timestamp  \
# 0   2023-11-27 13:52:33  1701067953
# 1   2023-11-27 10:00:05  1701054005
# 2   2023-11-26 23:33:43  1701016423
# 3   2023-11-25 23:56:02  1700931362
# 4   2023-11-25 22:36:49  1700926609
# ..                  ...         ...
# 185 2023-09-22 17:49:46  1695379786
# 186 2023-09-22 15:05:32  1695369932
# 187 2023-09-22 11:50:03  1695358203
# 188 2023-09-21 20:00:35  1695301235
# 189 2023-09-21 17:56:35  1695293795
#
#                                                  image  \
# 0                                                 None
# 1    https://scontent.fhan20-1.fna.fbcdn.net/v/t39....
# 2    https://scontent.fhan20-1.fna.fbcdn.net/v/t39....
# 3                                                 None
# 4    https://scontent.fhan20-1.fna.fbcdn.net/v/t39....
# ..                                                 ...
# 185                                               None
# 186  https://scontent.fhan20-1.fna.fbcdn.net/v/t39....
# 187  https://m.facebook.com/photo/view_full_size/?f...
# 188                                               None
# 189  https://scontent.fhan20-1.fna.fbcdn.net/v/t39....
#
#                                     images_description  likes  comments  \
# 0                                                   []    NaN      1197
# 1    [Có thể là hình ảnh về 13 người, đồ chơi, tay ...    NaN       126
# 2    [Có thể là hình ảnh về 1 người, đang chơi bóng...    NaN       342
# 3                                                   []    NaN       351
# 4    [Có thể là hình ảnh về đám đông và văn bản, Có...    NaN        52
# ..                                                 ...    ...       ...
# 185                                                 []    0.0         0
# 186  [Có thể là hình ảnh về 1 người và văn bản, Có ...    0.0         0
# 187         [Có thể là hình ảnh về 1 người và văn bản]    0.0         0
# 188                                                 []    0.0         0
# 189  [Có thể là hình ảnh về thuốc, sản phẩm chăm só...    0.0         0
#
#      shares                                           post_url  \
# 0       331  https://facebook.com/internetexplorerbeta/post...
# 1         0  https://facebook.com/internetexplorerbeta/post...
# 2       139  https://facebook.com/internetexplorerbeta/post...
# 3        55  https://facebook.com/internetexplorerbeta/post...
# 4         4  https://facebook.com/internetexplorerbeta/post...
# ..      ...                                                ...
# 185       0  https://facebook.com/internetexplorerbeta/post...
# 186       0  https://facebook.com/internetexplorerbeta/post...
# 187       0  https://facebook.com/internetexplorerbeta/post...
# 188       0  https://facebook.com/internetexplorerbeta/post...
# 189       0  https://facebook.com/internetexplorerbeta/post...
#
#              user_id                username  \
# 0    100064697200670  Internet Explorer Beta
# 1    100064697200670  Internet Explorer Beta
# 2    100064697200670  Internet Explorer Beta
# 3    100064697200670  Internet Explorer Beta
# 4    100064697200670  Internet Explorer Beta
# ..               ...                     ...
# 185  100064697200670  Internet Explorer Beta
# 186  100064697200670  Internet Explorer Beta
# 187  100064697200670  Internet Explorer Beta
# 188  100064697200670  Internet Explorer Beta
# 189  100064697200670  Internet Explorer Beta
#
#                                               user_url  is_live  \
# 0    https://facebook.com/internetexplorerbeta?lst=...    False
# 1    https://facebook.com/internetexplorerbeta?lst=...    False
# 2    https://facebook.com/internetexplorerbeta?lst=...    False
# 3    https://facebook.com/internetexplorerbeta?lst=...    False
# 4    https://facebook.com/internetexplorerbeta?lst=...    False
# ..                                                 ...      ...
# 185  https://facebook.com/internetexplorerbeta?eav=...    False
# 186  https://facebook.com/internetexplorerbeta?eav=...    False
# 187  https://facebook.com/internetexplorerbeta?eav=...    False
# 188  https://facebook.com/internetexplorerbeta?eav=...    False
# 189  https://facebook.com/internetexplorerbeta?eav=...    False
#
#                                              reactions  reaction_count  \
# 0    {'thích': 18943, 'yêu thích': 306, 'haha': 843...           28830
# 1    {'thích': 3740, 'yêu thích': 4, 'haha': 217, '...            3963
# 2    {'thích': 5331, 'yêu thích': 521, 'haha': 2199...            8125
# 3    {'thích': 2854, 'yêu thích': 15, 'haha': 2477,...            5913
# 4    {'thích': 3824, 'yêu thích': 14, 'haha': 74, '...            3918
# ..                                                 ...             ...
# 185                                               None               0
# 186                                               None               0
# 187                                               None               0
# 188                                               None               0
# 189                                               None               0
#
#              page_id
# 0    107278567503906
# 1    107278567503906
# 2    107278567503906
# 3    107278567503906
# 4    107278567503906
# ..               ...
# 185  107278567503906
# 186  107278567503906
# 187  107278567503906
# 188  107278567503906
# 189  107278567503906
#
# [190 rows x 17 columns]
